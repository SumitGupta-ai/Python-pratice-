# %%
# You are given a string. Split the string on a " " (space) delimiter and join using a - hyphen.
sent = input('Enter a sentence: ')
split_sent = sent.split(" ")
text_join = '-'.join(split_sent)
print(text_join)
# Out:
# Enter a sentence: sumit is good person
# sumit-is-good-person

# %%
# contact book list
def contact_book(n):
  contact = {}
  for i in range(n):
    name = input('Enter a name: ')
    number = int(input('Enter a Number: '))
    contact[name] = number

  search_name = input('Enter a search name: ')
  if search_name in contact:
    print(f"Phone Number of {search_name} is {contact[search_name]}")
  else:
    print(f"{search_name} not found")

n = int(input('How many number add your contact list: '))

contact_book(n)
# Out:
# How many number add your contact list: 1
# Enter a name: k
# Enter a Number: 78
# Enter a search name: k
# Phone Number of k is 78
