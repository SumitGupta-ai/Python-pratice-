# %%
a = 4
b = 5
c = a + b
print(c)
# Out:
# 9

# %%
def evenodd():
  n = int(input('Enter a number: '))
  if n % 2 == 0:
    return 'even number'
  else:
    return 'odd number'
print(evenodd())
# Out:
# Enter a number: 5
# odd number

# %%
num = [2,24,4]
sum = 0
for i in num:
  sum = sum + i
print(sum)
# Out:
# 30

# %%
lst = [4,5,1,2,6,8,7]
min_lst = min(lst)
max_lst = max(lst)
print(max_lst)
print(min_lst)
# Out:
# 8
# 1

# %%
num = [25,25,6,6,5,5]
print(list(set(num)))
# Out:
# [25, 5, 6]

# %%
num = [25,25,6,6,5,5]
unique_num = []
for i in num:
  if i not in unique_num:
    unique_num.append(i)
print(unique_num)
# Out:
# [25, 6, 5]

# %%
def rev():
  lst = [4,5,6]
  lst.reverse()
  return lst
print(rev())
# Out:
# [6, 5, 4]

# %%
lst = [4,5,6]
rev_lst = lst[:: -1]
print(rev_lst)
# Out:
# [6, 5, 4]

# %%
#  Create a tuple and access its elements.
tup = (2,3,4,5,6)
print(tup[0])
print(tup[2])
print(tup[3])
# Out:
# 2
# 4
# 5

# %%
import numpy as np
a = [9,5,3,1]
print(np.array(a))
# Out:
# [9 5 3 1]

# %%
a = np.array([2,3,4,5])
print(a)
# Out:
# [2 3 4 5]

# %%
a = np.array([[2,3,4], [4,5,6], [6,4,6]])
print(a)
print(a[0,1])
# Out:
# [[2 3 4]
#  [4 5 6]
#  [6 4 6]]
# 3

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])
c = np.add(a,b)
print(c)
# Out:
# [5 7 9]

# %%
#Write a program to merge two dictionaries
dict1 = {'name': 'sumit', 'couse': 'bca'}
dict2 = {'last_name': 'Gupta', 'goal': 'ai engineer'}
dict1.update(dict2)
print(dict1)
# Out:
# {'name': 'sumit', 'couse': 'bca', 'last_name': 'Gupta', 'goal': 'ai engineer'}

# %%
# Write a function to count the frequency of elements in a list
def count(lst):
  freq = {}

# %%
lst = ['apple', 'apple', 'banna', 'banna', 'sav']
freq = {}
for i in lst:
  if i in freq:
    freq[i] +=1
  else:
    freq[i] = 1
print(freq)
# Out:
# {'apple': 2, 'banna': 2, 'sav': 1}

# %%
from collections import Counter
lst = ['apple', 'ab','vc']
freq = Counter(lst)
print(freq)
# Out:
# Counter({'apple': 1, 'ab': 1, 'vc': 1})

# %%
square = {x: x**2 for x in range(1,11)}
print(square)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
lst = [2,1,3,4,3,1,2]
lst.sort()
print(lst)
# Out:
# [1, 1, 2, 2, 3, 3, 4]

# %%
dict1 = {'Pen': 'kalam', 'apple': 3}
key_to_check = 'apple'
if i in key_to_check:
  print(f'key {key_to_check} exite dict')
else:
  print(f"Key '{key_to_check}' does not exist.")
# Out:
# key apple exite dict

# %%
fruit = {'apple', 'banana', 'mangoes', 'pineapple'}
num = set([2,3,5,7])
a = fruit.union(num)
print(a)
# Out:
# {2, 3, 5, 7, 'banana', 'apple', 'mangoes', 'pineapple'}

# %%
def find_common_list(list1, list2):
  common = set(list1) & set(list2)
  return  list(common)
a = [1,2,2,3,6,4]
b = [1,2,3,4,5,6]
print(find_common_list(a,b))
# Out:
# [1, 2, 3, 4, 6]

# %%
def factorial(n):
  result = 1
  if n < 0:
    return 1
  for i in range(1, n+1):
    result *= i
  return result
n = int(input('Enter a factorial number: '))
print(factorial(n))
# Out:
# Enter a factorial number: 5
# 120

# %%
def factorial(n):
  fact = 1
  for i in range(1, n+1):
    fact *=i
  return fact

print(factorial(5))
# Out:
# 120

# %%
a = 'madam'
b = a[:: -1]
check = b==a
print(check)
# Out:
# True

# %%
def polidrome(text):
  return text == text[::-1]
print(polidrome('madam'))
# Out:
# False

# %%
name = 'madan'
check_poli = name[::-1]
if check_poli == name:
  print('its polidrome')
else:
  print('not polidrome')
# Out:
# not polidrome

# %%
name = 'sumit gupta'
count = 0
vowel = 'aeiou'
for i in name:
   if i in vowel:
    count +=1
print(count)
# Out:
# 4

# %%
def vowe_count(text):
  count = 0
  vowel = 'aeiou'
  for i in text:
    if i in vowel:
      count +=1
  return count
text = input('enter text: ')
print(vowe_count(text))
# Out:
# enter text: sumti
# 2
